# %%
import matplotlib.pyplot as plt

# Given values
results = [6, 4, 6, 4, 6, 6]
conditions = [f'Condition {i+1}' for i in range(len(results))]

# Create the plot
plt.figure(figsize=(8, 5))
plt.bar(conditions, results, color='skyblue')

# Set labels and title
plt.ylabel('Value')
plt.ylim(0, 9)  # Setting y-axis limit
plt.title('Correct per Condition')

plt.savefig('./Condition1Averages.png')
# Display the plot
plt.show()

# %%
# Given values
results = [8, 8, 16]
conditions = [f'Phrase {i+1}' for i in range(len(results))]

# Create the plot
plt.figure(figsize=(8, 5))
plt.bar(conditions, results, color='skyblue')

# Set labels and title
plt.ylabel('Value')
plt.ylim(0, 32)  # Setting y-axis limit
plt.title('Correct per Phrase')

plt.savefig('./Condition1Phrases.png')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Given values
results = [4, 7, 6, 5, 4, 7]
conditions = [f'Condition {i+1}' for i in range(len(results))]

# Create the plot
plt.figure(figsize=(8, 5))
plt.bar(conditions, results, color='skyblue')

# Set labels and title
plt.ylabel('Value')
plt.ylim(0, 9)  # Setting y-axis limit
plt.title('Correct per Condition')

plt.savefig('./Condition2Averages.png')

# Display the plot
plt.show()

# %%
# Given values
results = [10, 6, 17]
conditions = [f'Phrase {i+1}' for i in range(len(results))]

# Create the plot
plt.figure(figsize=(8, 5))
plt.bar(conditions, results, color='skyblue')

# Set labels and title
plt.ylabel('Value')
plt.ylim(0, 33)  # Setting y-axis limit
plt.title('Correct per Phrase')

plt.savefig('./Condition2Phrases.png')

# Display the plot
plt.show()
